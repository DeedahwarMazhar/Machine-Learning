# %%
import pandas as pd
from sklearn import tree
import sklearn.model_selection as model_selection
import numpy as np
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.naive_bayes import CategoricalNB
from sklearn.naive_bayes import GaussianNB
import graphviz as g
from sklearn import metrics
import matplotlib.pyplot as plt
from sklearn import preprocessing 
from sklearn import datasets

#CMS ID 243516---> modulus with 21 returns 16 so using dataset 16 monks problem 3.
#Deedahwar Mazhar BESE 9A lab 02 ML

# %%
file_test = pd.read_csv("/content/weather.csv") 

data=[]
train = []
test = []
max_depth = list(range(1, 17))
ord=preprocessing.OrdinalEncoder()
ord=ord.fit(file_test)
file_test[["weather", "temperature", "play"]]=ord.transform(file_test[["weather", "temperature", "play"]])
y=file_test["play"]
x=file_test.drop("play", axis=1)
alpha=[0,1]
for i in alpha:


  clf = CategoricalNB(alpha=i)
  clf.fit(x, y)
  print(clf.predict_proba([[2,1]]))
# Out:
# [[0.84375 0.15625]]
# [[0.71428571 0.28571429]]
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)

# %%
file_test = pd.read_csv("/content/16_monks-problems-3.csv", delimiter=";")
y=file_test.label
x=file_test.drop("label", axis=1)
ord=preprocessing.OrdinalEncoder()
x=ord.fit_transform(x)



x_train, x_test, y_train, y_test = model_selection.train_test_split(x,y, train_size=0.8, test_size=0.2)

clf=CategoricalNB()
clf.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print("Accuracy: ", metrics.accuracy_score(y_test,y_pred))
# Out:
# Accuracy:  0.9770114942528736

# %%
test=[]
train=[]
alpha=[]

for i in range(0, 51):
  clf = CategoricalNB(alpha=i)
  clf = clf.fit(x_train,y_train) 
  y_pred = clf.predict(x_test)
  accuracy=metrics.accuracy_score(y_test,y_pred)
  train.append(accuracy)
  clf = clf.fit(x_test,y_test) 
  y_pred = clf.predict(x_test)
  accuracy=metrics.accuracy_score(y_test,y_pred)
  test.append(accuracy)
  alpha.append(i)
 
  
  
  
  

plt.plot(alpha, train, label="train-accuracy")
plt.plot(alpha, test, label="test-accuracy")
plt.xlabel("Alpha")
plt.ylabel("Accuracy")
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)
# /usr/local/lib/python3.7/dist-packages/sklearn/naive_bayes.py:507: UserWarning: alpha too small will result in numeric errors, setting alpha = 1.0e-10
#   'setting alpha = %.1e' % _ALPHA_MIN)

# %%
dataset= sklearn.datasets.load_breast_cancer()
data=np.c_[dataset.data, dataset.target]
cols=np.append(dataset.feature_names,["target"])
file_test=pd.DataFrame(data, columns=cols)
y = file_test.target
x = file_test.drop("target", axis=1)

ord=preprocessing.OrdinalEncoder()
x=ord.fit_transform(x)
x_train, x_test, y_train, y_test = model_selection.train_test_split(x,y, train_size=0.8, test_size=0.2)
clf=GaussianNB()
clf.fit(x_train,y_train)
y_pred = clf.predict(x_test)
print("Train Error: ", 1-metrics.accuracy_score(y_test,y_pred))
clf.fit(x_test,y_test)
y_pred = clf.predict(x_test)
print("Test Error: ", 1-metrics.accuracy_score(y_test,y_pred))
# Out:
# Train Error:  0.052631578947368474
# Test Error:  0.04385964912280704
